# %%
# import the opencv library
import cv2

t_lower = 100  # Lower Threshold
t_upper = 150  # Upper threshold
  
# Applying the Canny Edge filter

# define a video capture object
vid = cv2.VideoCapture(0)

while(True):
    ret, frame = vid.read()
    edge = cv2.Canny(frame, t_lower, t_upper)
    cv2.imshow('frame', edge)
    

    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break


vid.release()
cv2.destroyAllWindows()

# %%
import cv2
from deepface import DeepFace
import numpy as np

face_cascade_name = cv2.data.haarcascades + 'haarcascade_frontalface_alt.xml'  
face_cascade = cv2.CascadeClassifier()  

if not face_cascade.load(cv2.samples.findFile(face_cascade_name)): 
    print("Error loading xml file")

video=cv2.VideoCapture(0) 

while True: 
    _,frame = video.read()

    gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)  #changing the video to grayscale to make the face analisis work properly
    face=face_cascade.detectMultiScale(gray,scaleFactor=1.1,minNeighbors=5)

    for x,y,w,h in face:
        frame=cv2.rectangle(frame,(x,y),(x+w,y+h),(0,0,255),1)
        
    try:
        analyze = DeepFace.analyze(frame,actions = ['emotion']) 
        print(analyze['dominant_emotion']) 
    except:
        print("no face")

    cv2.imshow('video', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

video.release()
cv2.destroyAllWindows()
# Out:
# facial_expression_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: C:\Users\win10\.deepface\weights\facial_expression_model_weights.h5
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 5.98M/5.98M [00:01<00:00, 5.67MB/s]
# no face
# fear
# no face
# no face
# fear
# fear
# sad
# neutral
# sad
# sad
# sad
# fear
# fear
# fear
# fear
# no face
# neutral
# neutral
# neutral
# neutral
# neutral
# happy
# happy
# happy
# happy
# happy
# happy
# happy
# happy
# happy
# happy
# happy
# neutral
# neutral
# neutral
# neutral
# sad
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# sad
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# sad
# sad
# neutral
# sad
# neutral
# neutral
# no face
# no face
# no face
# no face
# neutral
# no face
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# fear
# fear
# fear
# neutral
# surprise
# fear
# happy
# happy
# happy
# happy
# happy
# happy
# happy
# neutral
# no face
# happy
# angry
# neutral
# angry
# happy
# happy
# happy
# happy
# angry
# happy
# happy
# angry
# angry
# angry
# happy
# angry
# happy
# angry
# angry
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# no face
# no face
# no face
# no face
# no face
# no face
# no face
# no face
# no face
# happy
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# no face
# no face
# neutral
# no face
# no face
# no face
# no face
# no face
# no face
# no face
# neutral
# neutral
# no face
# sad
# neutral
# neutral
# neutral
# neutral
# no face
# no face
# no face
# no face
# no face
# no face
# no face
# no face
# no face
# no face
# no face
# no face
# no face
# no face
# no face
# no face
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# happy
# happy
# happy
# happy
# happy
# happy
# happy
# happy
# happy
# happy
# neutral
# happy
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# no face
# no face
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# no face
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# no face
# no face
# no face
# no face
# no face
# no face
# no face
# no face
# no face
# no face
# no face
# neutral
# no face
# no face
# no face
# no face
# no face
# no face
# no face
# no face
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# sad
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# sad
# neutral
# neutral
# neutral
# sad
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# no face
# no face
# no face
# no face
# fear
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [1], in <module>
#      14 _,frame = video.read()
#      16 gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)  #changing the video to grayscale to make the face analisis work properly
# ---> 17 face=face_cascade.detectMultiScale(gray,scaleFactor=1.1,minNeighbors=5)
#      19 for x,y,w,h in face:
#      20     frame=cv2.rectangle(frame,(x,y),(x+w,y+h),(0,0,255),1)
#
# KeyboardInterrupt:
